# %% [markdown]
# <a href="https://colab.research.google.com/github/mithileshpatra11/EDA-on-Udemy-dataset/blob/main/udemy_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Udemy Courses dataset**

# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('/content/sample_data/myfolder/udemy_courses.csv')

# %%
data
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %% [markdown]
# **1. Display Top 10 Rows of The Dataset**

# %%
data.head(10)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
# 5     192870  Trading Penny Stocks: A Guide for All Levels I...
# 6     739964  Investing And Trading For Beginners: Mastering...
# 7     403100  Trading Stock Chart Patterns For Immediate, Ex...
# 8     476268  Options Trading 3 : Advanced Stock Profit and ...
# 9    1167710  The Only Investment Strategy You Need For Your...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# ...

# %% [markdown]
# **2. Check Last 5 Rows of The Dataset**

# %%
data.tail()
# Out:
#       course_id                                       course_title  \
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 3673  https://www.udemy.com/easy-jquery-for-beginner...     True    100
# 3674  https://www.udemy.com/how-to-make-a-wordpress-...     True     25
# 3675  https://www.udemy.com/learn-and-build-using-po...     True     40
# 3676  https://www.udemy.com/css-animations-create-am...     True     50
# 3677  https://www.udemy.com/using-modx-cms-to-build-...     True     45
#
#       num_subscribers  num_reviews  num_lectures           level  \
# ...

# %% [markdown]
# **3. Find Shape of Our Dataset (Number of Rows And Number of Columns)**

# %%
shape = data.shape
print(f'The number of rows are {data.shape[0]} and columns are {data.shape[1]}')
# Out:
# The number of rows are 3678 and columns are 12

# %% [markdown]
# **4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   object
#  11  subject              3678 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(5)
# memory usage: 319.8+ KB

# %% [markdown]
# *DATA CLEANING*
#
#
# 1.   NULL
# 2.   REMOVE UNNESESARY COLUMNS
# 3.   DUPLICATE
# 4.   COLUMN TYPE
# 5.   RELATION CATEGORICAL COLUMNS

# %%
data.isnull().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
print(f'Is there any null values in the dataset? {data.isnull().values.any()}')
# Out:
# Is there any null values in the dataset? False

# %%
sns.heatmap(data.isnull());

# %% [markdown]
# REMOVE UNNESESARY COLUMNS

# %%
data.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
data.drop('url', axis=1, inplace=True)
data.drop('course_id', axis=1, inplace=True)

# %%
data
# Out:
#                                            course_title  is_paid  price  \
# 0                    Ultimate Investment Banking Course     True    200
# 1     Complete GST Course & Certification - Grow You...     True     75
# 2     Financial Modeling for Business Analysts and C...     True     45
# 3     Beginner to Pro - Financial Analysis in Excel ...     True     95
# 4          How To Maximize Your Profits Trading Options     True    200
# ...                                                 ...      ...    ...
# 3673  Learn jQuery from Scratch - Master of JavaScri...     True    100
# 3674  How To Design A WordPress Website With No Codi...     True     25
# 3675                      Learn and Build using Polymer     True     40
# 3676  CSS Animations: Create Amazing Effects on Your...     True     50
# 3677  Using MODX CMS to Build Websites: A Beginner's...     True     45
#
#       num_subscribers  num_reviews  num_lectures               level  \
# ...

# %%
data.dtypes
# Out:
# course_title            object
# is_paid                   bool
# price                    int64
# num_subscribers          int64
# num_reviews              int64
# num_lectures             int64
# level                   object
# content_duration       float64
# published_timestamp     object
# subject                 object
# dtype: object

# %%
data['published_timestamp'] = pd.to_datetime(data['published_timestamp'])

# %%
data.dtypes
# Out:
# course_title                        object
# is_paid                               bool
# price                                int64
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                   float64
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %% [markdown]
# show data that duplicate

# %%
data.duplicated().any()
# Out:
# True

# %%
data[data.duplicated()]
# Out:
#                                            course_title  is_paid  price  \
# 787   Essentials of money value: Get a financial Life !     True     20
# 788   Introduction to Forex Trading Business For Beg...     True     20
# 894                  Understanding Financial Statements     True     25
# 1100                  CFA Level 2- Quantitative Methods     True     40
# 1473                             MicroStation - Células     True     20
# 2561  Learn Web Designing & HTML5/CSS3 Essentials in...     True     75
#
#       num_subscribers  num_reviews  num_lectures           level  \
# 787                 0            0            20      All Levels
# 788                 0            0            27  Beginner Level
# 894                 0            0            10      All Levels
# 1100                0            0            35      All Levels
# 1473                0            0             9  Beginner Level
# 2561            43285          525            24      All Levels
#
# ...

# %%
data.drop_duplicates(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3672 entries, 0 to 3677
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_title         3672 non-null   object
#  1   is_paid              3672 non-null   bool
#  2   price                3672 non-null   int64
#  3   num_subscribers      3672 non-null   int64
#  4   num_reviews          3672 non-null   int64
#  5   num_lectures         3672 non-null   int64
#  6   level                3672 non-null   object
#  7   content_duration     3672 non-null   float64
#  8   published_timestamp  3672 non-null   datetime64[ns, UTC]
#  9   subject              3672 non-null   object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(1), int64(4), object(3)
# memory usage: 290.5+ KB

# %% [markdown]
# visualize
#
#
# 1.   start with categorical
# 2.   find relation between columns

# %%
data.head()
# Out:
#                                         course_title  is_paid  price  \
# 0                 Ultimate Investment Banking Course     True    200
# 1  Complete GST Course & Certification - Grow You...     True     75
# 2  Financial Modeling for Business Analysts and C...     True     45
# 3  Beginner to Pro - Financial Analysis in Excel ...     True     95
# 4       How To Maximize Your Profits Trading Options     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# 1             2792          923           274          All Levels
# 2             2174           74            51  Intermediate Level
# 3             2451           11            36          All Levels
# 4             1276           45            26  Intermediate Level
#
#    content_duration       published_timestamp           subject
# 0               1.5 2017-01-18 20:58:58+00:00  Business Finance
# ...

# %%
import matplotlib.pyplot as plt

# %%
sns.set_theme(style="whitegrid")
sns.countplot(x=data['is_paid']);
plt.title('Paid vs free courses');

# %%
data['is_paid'].value_counts()
# Out:
# True     3362
# False     310
# Name: is_paid, dtype: int64

# %%
data['is_paid'].value_counts().plot(kind='bar');

# %%
data
# Out:
#                                            course_title  is_paid  price  \
# 0                    Ultimate Investment Banking Course     True    200
# 1     Complete GST Course & Certification - Grow You...     True     75
# 2     Financial Modeling for Business Analysts and C...     True     45
# 3     Beginner to Pro - Financial Analysis in Excel ...     True     95
# 4          How To Maximize Your Profits Trading Options     True    200
# ...                                                 ...      ...    ...
# 3673  Learn jQuery from Scratch - Master of JavaScri...     True    100
# 3674  How To Design A WordPress Website With No Codi...     True     25
# 3675                      Learn and Build using Polymer     True     40
# 3676  CSS Animations: Create Amazing Effects on Your...     True     50
# 3677  Using MODX CMS to Build Websites: A Beginner's...     True     45
#
#       num_subscribers  num_reviews  num_lectures               level  \
# ...

# %%
plt.figure(figsize=(8,6));
sns.countplot(x=data['level']);
plt.title('level analysis');

# %%
data.head()
# Out:
#                                         course_title  is_paid  price  \
# 0                 Ultimate Investment Banking Course     True    200
# 1  Complete GST Course & Certification - Grow You...     True     75
# 2  Financial Modeling for Business Analysts and C...     True     45
# 3  Beginner to Pro - Financial Analysis in Excel ...     True     95
# 4       How To Maximize Your Profits Trading Options     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# 1             2792          923           274          All Levels
# 2             2174           74            51  Intermediate Level
# 3             2451           11            36          All Levels
# 4             1276           45            26  Intermediate Level
#
#    content_duration       published_timestamp           subject
# 0               1.5 2017-01-18 20:58:58+00:00  Business Finance
# ...

# %%
data['subject'].value_counts()
# Out:
# Web Development        1199
# Business Finance       1191
# Musical Instruments     680
# Graphic Design          602
# Name: subject, dtype: int64

# %%
plt.figure(figsize=(10,8));
sns.countplot(x=data['subject']);
plt.title('subject analysis');

# %%
plt.figure(figsize=(12,8));
sns.regplot(data=data, x='price', y='num_subscribers');
plt.title('Subscribe vs price');

# %% [markdown]
#  CONCLUSION: course price dose not effect num of subscripers

# %% [markdown]
# #number of reviews vs pric

# %%
plt.figure(figsize=(12,8));
sns.scatterplot(data=data, x='price', y='num_reviews');
plt.title('num_reviews vs price');

# %% [markdown]
# #number of duration vs pric

# %%
plt.figure(figsize=(12,8));
sns.regplot(data=data, x='price', y='content_duration');
plt.title('content_duration vs price');

# %% [markdown]
# relation between subscribers and content duration

# %%
data.head()
# Out:
#                                         course_title  is_paid  price  \
# 0                 Ultimate Investment Banking Course     True    200
# 1  Complete GST Course & Certification - Grow You...     True     75
# 2  Financial Modeling for Business Analysts and C...     True     45
# 3  Beginner to Pro - Financial Analysis in Excel ...     True     95
# 4       How To Maximize Your Profits Trading Options     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# 1             2792          923           274          All Levels
# 2             2174           74            51  Intermediate Level
# 3             2451           11            36          All Levels
# 4             1276           45            26  Intermediate Level
#
#    content_duration       published_timestamp           subject
# 0               1.5 2017-01-18 20:58:58+00:00  Business Finance
# ...

# %%
plt.figure(figsize=(12,8));
sns.regplot(data=data, x='num_subscribers', y='content_duration');
plt.title('num_subscribers vs content_duration');

# %% [markdown]
# CONCLUSION: course duration leads to more subscribers

# %% [markdown]
# Find Out Number of Courses Per Subjects

# %%
data.head()
# Out:
#                                         course_title  is_paid  price  \
# 0                 Ultimate Investment Banking Course     True    200
# 1  Complete GST Course & Certification - Grow You...     True     75
# 2  Financial Modeling for Business Analysts and C...     True     45
# 3  Beginner to Pro - Financial Analysis in Excel ...     True     95
# 4       How To Maximize Your Profits Trading Options     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# 1             2792          923           274          All Levels
# 2             2174           74            51  Intermediate Level
# 3             2451           11            36          All Levels
# 4             1276           45            26  Intermediate Level
#
#    content_duration       published_timestamp           subject
# 0               1.5 2017-01-18 20:58:58+00:00  Business Finance
# ...

# %%
result = data['subject'].value_counts()
result
# Out:
# Web Development        1199
# Business Finance       1191
# Musical Instruments     680
# Graphic Design          602
# Name: subject, dtype: int64

# %%
plt.figure(figsize=(12,8));
sns.countplot(x=data['subject']);
plt.title('Number of Courses Per Subjects');
plt.xlabel('subjects', fontsize=15);
plt.ylabel('Number of Courses Per Subjects', fontsize=13);

# %% [markdown]
# For Which Levels, Udemy Courses Providing The Courses

# %%
data.head()
# Out:
#                                         course_title  is_paid  price  \
# 0                 Ultimate Investment Banking Course     True    200
# 1  Complete GST Course & Certification - Grow You...     True     75
# 2  Financial Modeling for Business Analysts and C...     True     45
# 3  Beginner to Pro - Financial Analysis in Excel ...     True     95
# 4       How To Maximize Your Profits Trading Options     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# 1             2792          923           274          All Levels
# 2             2174           74            51  Intermediate Level
# 3             2451           11            36          All Levels
# 4             1276           45            26  Intermediate Level
#
#    content_duration       published_timestamp           subject
# 0               1.5 2017-01-18 20:58:58+00:00  Business Finance
# ...

# %%
data['level'].value_counts()
# Out:
# All Levels            1925
# Beginner Level        1268
# Intermediate Level     421
# Expert Level            58
# Name: level, dtype: int64

# %%
plt.figure(figsize=(12,8));
sns.countplot(x=data['level']);
plt.title('levels vs courses');
plt.xlabel('levels', fontsize=13);
plt.ylabel('No. of courses', fontsize=13);

# %% [markdown]
# Display The Count of Paid and Free Courses

# %%
data['is_paid'].value_counts()
# Out:
# True     3362
# False     310
# Name: is_paid, dtype: int64

# %% [markdown]
# Which Course Has More Lectures (Free or Paid)?

# %%
data.groupby(['is_paid']).mean()
# Out:
#              price  num_subscribers  num_reviews  num_lectures  \
# is_paid
# False     0.000000     11533.951613   425.929032     21.416129
# True     72.198096      2421.270077   131.516359     41.866746
#
#          content_duration
# is_paid
# False            2.210753
# True             4.271584

# %% [markdown]
# Which Courses Have A Higher Number of Subscribers Free or Paid?

# %%
data.groupby(by='is_paid').mean()
# Out:
#              price  num_subscribers  num_reviews  num_lectures  \
# is_paid
# False     0.000000     11533.951613   425.929032     21.416129
# True     72.198096      2421.270077   131.516359     41.866746
#
#          content_duration
# is_paid
# False            2.210753
# True             4.271584

# %%
plt.figure(figsize=(12,8));
sns.barplot(data=data, x='is_paid', y='num_subscribers');
plt.title('num_subscribers vs is_paid');

# %% [markdown]
#  Which Level Has The Highest Number of Subscribers?

# %%
data.head()
# Out:
#                                         course_title  is_paid  price  \
# 0                 Ultimate Investment Banking Course     True    200
# 1  Complete GST Course & Certification - Grow You...     True     75
# 2  Financial Modeling for Business Analysts and C...     True     45
# 3  Beginner to Pro - Financial Analysis in Excel ...     True     95
# 4       How To Maximize Your Profits Trading Options     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# 1             2792          923           274          All Levels
# 2             2174           74            51  Intermediate Level
# 3             2451           11            36          All Levels
# 4             1276           45            26  Intermediate Level
#
#    content_duration       published_timestamp           subject
# 0               1.5 2017-01-18 20:58:58+00:00  Business Finance
# ...

# %%
data.groupby(by='level').mean()
# Out:
#                      is_paid      price  num_subscribers  num_reviews  \
# level
# All Levels          0.936623  73.090909      3569.761558   209.751688
# Beginner Level      0.875394  55.737382      3195.459779   101.794164
# Expert Level        1.000000  91.120690       865.448276    40.224138
# Intermediate Level  0.928741  61.923990      1762.482185    92.674584
#
#                     num_lectures  content_duration
# level
# All Levels             46.030649          4.874000
# Beginner Level         33.022082          3.094401
# Expert Level           30.775862          2.905460
# Intermediate Level     35.935867          3.733333

# %%
plt.figure(figsize=(12,8));
sns.barplot(data=data, x='level', y='num_subscribers');
plt.title('num_subscribers vs level');
plt.xlabel('level', fontsize=13);
plt.ylabel('num_subscribers', fontsize=13);

# %% [markdown]
# Find Most Popular Course Title

# %%
data.head()
# Out:
#                                         course_title  is_paid  price  \
# 0                 Ultimate Investment Banking Course     True    200
# 1  Complete GST Course & Certification - Grow You...     True     75
# 2  Financial Modeling for Business Analysts and C...     True     45
# 3  Beginner to Pro - Financial Analysis in Excel ...     True     95
# 4       How To Maximize Your Profits Trading Options     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# 1             2792          923           274          All Levels
# 2             2174           74            51  Intermediate Level
# 3             2451           11            36          All Levels
# 4             1276           45            26  Intermediate Level
#
#    content_duration       published_timestamp           subject
# 0               1.5 2017-01-18 20:58:58+00:00  Business Finance
# ...

# %%
data[data['num_subscribers'].max() == data['num_subscribers']]['course_title']
# Out:
# 2827    Learn HTML5 Programming From Scratch
# Name: course_title, dtype: object

# %% [markdown]
# Display 10 Most Popular Courses As Per Number of Subscribers

# %%
data.sort_values(by='num_subscribers', ascending=False).head(10)
# Out:
#                                            course_title  is_paid  price  \
# 2827               Learn HTML5 Programming From Scratch    False      0
# 3032                     Coding for Entrepreneurs Basic    False      0
# 3230                         The Web Developer Bootcamp     True    200
# 2783  Build Your First Website in 1 Week with HTML5 ...    False      0
# 3232              The Complete Web Developer Course 2.0     True    200
# 1896              Free Beginner Electric Guitar Lessons    False      0
# 2589  Web Design for Web Developers: Build Beautiful...    False      0
# 2619             Learn Javascript & JQuery From Scratch     True     30
# 3289  Practical PHP: Master the Basics and Code Dyna...    False      0
# 3247          JavaScript: Understanding the Weird Parts     True    175
#
#       num_subscribers  num_reviews  num_lectures           level  \
# 2827           268923         8629            45      All Levels
# ...

# %% [markdown]
# Find The Course Which Is Having The Highest Number of Reviews.

# %%
data[data['num_reviews'].max() == data['num_reviews']]['course_title']
# Out:
# 3230    The Web Developer Bootcamp
# Name: course_title, dtype: object

# %% [markdown]
#  Does Price Affect the Number of Reviews?

# %%
plt.figure(figsize=(12,8));
sns.regplot(data=data, x='price', y='num_reviews');
plt.title('price vs num_reviews');

# %% [markdown]
# Find Total Number of Courses Related To Python

# %%
len(data[data['course_title'].str.contains('python',case=False)])
# Out:
# 29

# %% [markdown]
# Display 10 Most Popular Python Courses As Per Number of Subscribers

# %%
result=data[data['course_title'].str.contains('python', case=False)].sort_values(by='num_subscribers', ascending=False).head(10)
result
# Out:
#                                            course_title  is_paid  price  \
# 2497                        Web Programming with Python     True     50
# 2570  Coding for Entrepreneurs: Learn Python, Django...     True    195
# 2528        Learn Python and Django: Payment Processing     True     70
# 3200  Python and Django Full Stack Web Developer Boo...     True    200
# 3507  Fun and creative web engineering with Python a...    False      0
# 2553  The Complete Ethical Hacking Course 2.0: Pytho...     True    195
# 3138  Complete Python Web Course: Build 8 Python Web...     True    110
# 3197  Try Django 1.9 | Build a Blog and Learn Python...     True     50
# 2681  Python for Beginners: Python Programming Langu...     True    150
# 3203                    REST APIs with Flask and Python     True    110
#
#       num_subscribers  num_reviews  num_lectures               level  \
# 2497            35267          217            53          All Levels
# ...

# %%
plt.figure(figsize=(12,8));
sns.barplot(data=result, x='num_subscribers', y='course_title');
plt.title('num_subscribers vs course_title');
plt.xlabel('number of subscribers', fontsize=13);
plt.ylabel('course_title', fontsize=13);

# %% [markdown]
#  In Which Year The Highest Number of Courses Were Posted?

# %%
data.head()
# Out:
#                                         course_title  is_paid  price  \
# 0                 Ultimate Investment Banking Course     True    200
# 1  Complete GST Course & Certification - Grow You...     True     75
# 2  Financial Modeling for Business Analysts and C...     True     45
# 3  Beginner to Pro - Financial Analysis in Excel ...     True     95
# 4       How To Maximize Your Profits Trading Options     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# 1             2792          923           274          All Levels
# 2             2174           74            51  Intermediate Level
# 3             2451           11            36          All Levels
# 4             1276           45            26  Intermediate Level
#
#    content_duration       published_timestamp           subject
# 0               1.5 2017-01-18 20:58:58+00:00  Business Finance
# ...

# %%
data['Year'] = data['published_timestamp'].dt.year

# %%
plt.figure(figsize=(12,8));
sns.countplot(x=data['Year']);

# %% [markdown]
# Display Category-Wise Count of Posted Subjects [Year Wise]

# %%
data.head()
# Out:
#                                         course_title  is_paid  price  \
# 0                 Ultimate Investment Banking Course     True    200
# 1  Complete GST Course & Certification - Grow You...     True     75
# 2  Financial Modeling for Business Analysts and C...     True     45
# 3  Beginner to Pro - Financial Analysis in Excel ...     True     95
# 4       How To Maximize Your Profits Trading Options     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# 1             2792          923           274          All Levels
# 2             2174           74            51  Intermediate Level
# 3             2451           11            36          All Levels
# 4             1276           45            26  Intermediate Level
#
#    content_duration       published_timestamp           subject  Year
# 0               1.5 2017-01-18 20:58:58+00:00  Business Finance  2017
# ...

# %%
data.groupby(by='Year')['subject'].value_counts()
# Out:
# Year  subject
# 2011  Web Development          5
# 2012  Web Development         19
#       Graphic Design          10
#       Musical Instruments     10
#       Business Finance         6
# 2013  Business Finance        84
#       Web Development         55
#       Musical Instruments     39
#       Graphic Design          23
# 2014  Business Finance       192
#       Musical Instruments    120
#       Web Development        113
#       Graphic Design          65
# 2015  Business Finance       339
#       Web Development        336
#       Musical Instruments    171
#       Graphic Design         168
# 2016  Web Development        448
#       Business Finance       347
#       Musical Instruments    228
#       Graphic Design         181
# 2017  Business Finance       223
#       Web Development        223
#       Graphic Design         155
#       Musical Instruments    112
# Name: subject, dtype: int64
